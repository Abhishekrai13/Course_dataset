# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
colname=['Sr.No','Cities','Institute','Courser','City','Months']
df=pd.read_csv("course.csv",header=None,names=colname)
df
# Out:
#     Sr.No     Cities                 Institute       Courser City     Months
# 0       1     Mumbai        PQR institute .Pvt            BI   MH   9 Months
# 1       2      Delhi    ABC institute .Pvt.LTD            AI   UP  18 Months
# 2       3  Bengaluru       MNO  institute .Ltd  Data Science   TN  11 Months
# 3       4     Bhopal   RST  institute .Pvt.LTD            ML   MP   3 Months
# 4       5     Mumbai   EFG  institute .Pvt.LTD            DL   MH   3 Months
# 5       6  Hyderabad           LMN  institute          Could   AP   4 Months
# 6       7      Patna      DEF   institute .Ltd      Web Serv   BH   4 Months
# 7       8    Channai   PQR  institute .Pvt.LTD           AWS   KT   3 Months
# 8       9    Kolkata       UVW  institute .Ltd    Networking   WB   3 Months
# 9      10  Hyderabad      GHI   institute .Ltd            AI   AP  18 Months
# 10     11     Bhopal          IJK   institute             DL   MP   3 Months
# ...

# %%
df.head()
# Out:
#    Sr.No     Cities                Institute       Courser City     Months
# 0      1     Mumbai       PQR institute .Pvt            BI   MH   9 Months
# 1      2      Delhi   ABC institute .Pvt.LTD            AI   UP  18 Months
# 2      3  Bengaluru      MNO  institute .Ltd  Data Science   TN  11 Months
# 3      4     Bhopal  RST  institute .Pvt.LTD            ML   MP   3 Months
# 4      5     Mumbai  EFG  institute .Pvt.LTD            DL   MH   3 Months

# %%
df.info()
#In the given data 6 columns and 25 rows
#there is no any float type data and only on is int type data in the table
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Sr.No      25 non-null     int64
#  1   Cities     25 non-null     object
#  2   Institute  25 non-null     object
#  3   Courser    25 non-null     object
#  4   City       25 non-null     object
#  5   Months     25 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 1.3+ KB

# %%
df.describe()
#There are overall 25 samples in the dataset
#The avg of months is concentrated around 13 i.e overall the user are in other course.
#the avg months may vary between 1 - 25
#the months remaings ranges between 1 - 25
#star rating exhibits +ve skewness since, mean is greater then median.
#50% courser is below 13 and rest above it
# Out:
#            Sr.No
# count  25.000000
# mean   13.000000
# std     7.359801
# min     1.000000
# 25%     7.000000
# 50%    13.000000
# 75%    19.000000
# max    25.000000

# %%
df[['Cities']].value_counts()
#Most cities people is come from Mumbai and least people come from kolkata.
#Equalliy come from delhi,hyderabad and patana
#similarly reamming people come from bengaluru,bhopal,chennai,pune,and surat
# Out:
# Cities
# Mumbai       5
# Delhi        3
# Hyderabad    3
# Patna        3
# Bengaluru    2
# Bhopal       2
# Channai      2
# Pune         2
# Surat        2
# Kolkata      1
# dtype: int64

# %%
df[['Courser']].value_counts()
#most of the people is doing DataScience and only one person is doing Networking
#only 2 people is doing BI.
#And remaining people with pair of 3 is doing AI,AWS,COULD,DL,ML,WEB SERV.
# Out:
# Courser
# Data Science    4
# AI              3
# AWS             3
# Could           3
# DL              3
# ML              3
# Web Serv        3
# BI              2
# Networking      1
# dtype: int64

# %%
df[['Months']].value_counts()
#most of people is at age compelting there course like 11 people is remaing 3 months
#and 5 people have 4 months,
#and 4 people have 11 months courser
#and only 3 people have 18 months course remaining 
#and only 1,1 people have 6 or 9 months courser remaining
# Out:
# Months
# 3 Months     11
# 4 Months      5
# 11 Months     4
# 18 Months     3
# 6 Months      1
# 9 Months      1
# dtype: int64

# %%
plt.figure(figsize=(8,8))
sns.countplot(data=df,y='Cities')
plt.show()
#Most people is come from mumbai.

# %%
plt.figure(figsize=(17,8))
sns.countplot(data=df,x='Cities',hue="Courser")
plt.tight_layout()
plt.grid(True)
plt.show()
#In mumbai most of 2% people  is doing Dl and remaining 1% people is doing BI , Web Serv or Cloud course.
#In delhi all 1% people is doing BI,AI and AWS
#In Bengaluru all 1% people is doing AI and Data Science.
#In Bopal all 1% people doing ML and

# %%
corr=df.corr()
plt.figure(figsize=(6,6))
a=sns.heatmap(corr,annot=True,cmap='viridis')
#IN OUR GIVEN DATASET IS POSITIVLY SKEWED.
